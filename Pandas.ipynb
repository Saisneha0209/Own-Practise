# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/Own-Practise/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s = pd.Series([10,20,30,40,50,60])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name = "Calories"

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: Calories, dtype: int64

# %%
a = pd.Series([10,20,30,40,50,60])
print(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
a.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
a.values
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
a.name = "AGAIN NUMBERS"

# %%
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: AGAIN NUMBERS, dtype: int64

# %%
#INDEXING!!
s[1]
# Out:
# np.int64(20)

# %%
a[0]
# Out:
# np.int64(10)

# %%
s[0:2]
# Out:
# 0    10
# 1    20
# Name: Numbers, dtype: int64

# %%
s[2:4]
# Out:
# 2    30
# 3    40
# Name: Numbers, dtype: int64

# %%
#iloc :- Location - Based Indexing!!
s.iloc[3]
# Out:
# np.int64(40)

# %%
s.iloc[[1,3,4]]
# Out:
# 1    20
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
index = ['apple','banana','grapes','pineapple','tomato','potato']
s.index = index
s
# Out:
# apple        10
# banana       20
# grapes       30
# pineapple    40
# tomato       50
# potato       60
# Name: Calories, dtype: int64

# %%
s.loc['grapes']
# Out:
# np.int64(30)

# %%
#loc -.label - based indexing!!

# %%
#In label based indexing your start as well as stop values both are included in the output!!

# %%
s['banana':'potato']
# Out:
# banana       20
# grapes       30
# pineapple    40
# tomato       50
# potato       60
# Name: Calories, dtype: int64

# %%
s.loc[['grapes','banana','potato']]
# Out:
# grapes    30
# banana    20
# potato    60
# Name: Calories, dtype: int64

# %%
fruit_protein = {"avocado":567,
                 "Guava":345,
                 "potato":456,
                 "orange":789,
                 "berry":456,
                 "perry":420}

# %%
s2 = pd.Series(fruit_protein, name = "Protein")

# %%
s2
# Out:
# avocado    567
# Guava      345
# potato     456
# orange     789
# berry      456
# perry      420
# Name: Protein, dtype: int64

# %%
#CONDITIONAL SELECTION:-
s2[s2>500]
# Out:
# avocado    567
# orange     789
# Name: Protein, dtype: int64

# %%
#LOGICAL OPERATORS :-
#AND and OR....
#notnull() gives a bracket of values which are not null..
#and sum gives the number of the list as per the 0 and 1 assigned to them!!

# %%
#df = pd.read("given data name")
#df.head(10)
#df.tail(5)

# %%
#loc and iloc

# %%
#df.iloc[1:3]
#df.loc[1:2,['age','department]]
#df.['Age']
#df.drop("Age",axis = 1,inplace = True)1 is for that column and axis = 0 is for a particular row to be gone!!
#inplace means performing operations in out original data!!otherwise by default it is false..
#df.shape()
#df.info()
#df.describe()

# %%
#BroadCasting!!
#df.rename = (columns = {"department":"age"}, inplace = True)
#df.unique() to check the values that are unique in your data!!

# %%
#df["column name"].value_counts() this means there are how many things in a particular column..

# %%
#DATA - CLEANING!!
#df.isnull().sum()
#IF WE FIND ANY TYPE OF NULL VALUES IN THE DATA EITHER WE CAN DROP IT OR EITHER WE CAN FILL IT WITH THE MOST REPEATED VALUES OR EITHER WE HAVE TO PASS THAT ARGUMENT TO THAT IN FILL.NA(0)
#df.dropna(how ="any") #which ever row has any null values it will drop out!!
#df.fillna(0) THIS WILL FILL OUT THE COLUMN WHICHEVER HAS THE NULL VALUES!!

# %%
#DF ["AGE"].FILLNA(method = "ffill")
#there are forward fill and then the backward fill soo forward mai agae usse pehla vala hoghga toh vo value and
#in backward fill jo null value ke baad vala hoga uski value will be placed there!!

# %%
#df_dup = df[df.duplicated(keep = "last")]
#df_dup
#df = df.drop_duplicates()
#lamda function!!

# %%
#str.split("_")

# %%
#pd.concat([df,df2])
